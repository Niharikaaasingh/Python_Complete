# %% [markdown]
# <a href="https://colab.research.google.com/github/Niharikaaasingh/Python_Complete/blob/main/6_OOP_Class%26Object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#objectname = classname()
L = list()
L
# Out:
# []

# %%
class Atm:
  #constructor(special function)->superpower->
  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()


  def menu(self):
    user_input = input(
        """
        HI how can I help you
        1.press 1 to create pin
        2.press 2 to change pin
        3.press 3 to check balance
        4.press 4 to withdraw
        5.Anything else to exit
      """
    )

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
      pass
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance

    print('pin created successfully')
    self.menu()

  def change_pin(self):
    old_pin = input("enter old pin")
    if old_pin == self.pin:
      #let this change the pin
      new_pin = input("enter new pin")
      self.pin = new_pin
      print('pin changed successfully')
      self.menu()
    else:
      print('nai krne de skta h re baba')
      self.menu()

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is', self.balance)
    else:
      print('chal nikal yhan se')
    self.menu()


  def withdraw(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      #allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('withdrawl successful balance is', self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')
    self.menu()














obj = Atm()
# Out:
#         HI how can I help you
#         1.press 1 to create pin
#         2.press 2 to change pin
#         3.press 3 to check balance
#         4.press 4 to withdraw
#         5.Anything else to exit
#       1
# enter your pin1234
# enter balance2222
# pin created successfully
#
#         HI how can I help you
#         1.press 1 to create pin
#         2.press 2 to change pin
#         3.press 3 to check balance
#         4.press 4 to withdraw
#         5.Anything else to exit
#       2
# enter old pin1234
# enter new pin1111
# pin changed successfully
#
#         HI how can I help you
#         1.press 1 to create pin
#         2.press 2 to change pin
#         3.press 3 to check balance
#         4.press 4 to withdraw
#         5.Anything else to exit
#       3
# enter your pin1111
# your balance is 2222
#
#         HI how can I help you
#         1.press 1 to create pin
#         2.press 2 to change pin
#         3.press 3 to check balance
#         4.press 4 to withdraw
# ...

# %%
L = [1,2,3]
len(L)  #funcion-> it is outside the class
L.append(4) #method -> it is under the class

# %%
class temp:

  def __init__(self):
    print('hello')

obj = temp()
# Out:
# hello

# %%
class Fraction:
  #parameterized constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    new_num = self.den * other.num +  other.den * self.num
    new_den = self.den * other.den


    return '{}/{}'.format(new_num,new_den)
  def __sub__(self,other):
    new_num = self.den * other.num - other.den * self.num
    new_den = self.den * other.den

    return '{}/{}'.format(new_num,new_den)

  def __mul__(self,other):
    new_num = self.num*other.num
    new_den = self.den * other.den

    return '{}/{}'.format(new_num,new_den)

  def __truediv__(self,other):
    new_num = self.num*other.den
    new_den = self.den * other.num

    return '{}/{}'.format(new_num,new_den)

  def convert_to_decimal(self):
    return self.num/self.den

# %%
fr1  = Fraction(3,4)
fr2 = Fraction(1,2)

# %%
print(fr1)
print(fr2)
#3/4
# Out:
# 3/4
# 1/2

# %%
print(fr1 +fr2 )
print(fr1 - fr2)
print(fr1*fr2)
print(fr1/fr2)
fr1.convert_to_decimal()
# Out:
# 10/8
# -2/8
# 3/8
# 6/4
# 0.75

# %%
# Out:
# -2/8

# %%
# Out:
# 3/8

# %%
# Out:
# 6/4

# %% [markdown]
# #Write oop to handle the following scenarios:
#
# * A user can create and view 2D coordinators
# * A user can find out the distance between 2 coordinates
# * A user can find the distance of coordinates from origin
# * A user can check if a point lies on given line
# * A user can find the shortest distance between a given 2D point and a given line

# %%
class point:

  def __init__(self,x,y):
    self.x_cod = x
    self.y_cod = y
# A user can create and view 2D coordinators
  def __str__(self):
    return '<{},{}>'.format(self.x_cod,self.y_cod)

# A user can find out the distance between 2 coordinates
  def euclidean_distance(self,other):
    return ((self.x_cod - other.x_cod)**2 + (self.y_cod - other.y_cod)**2 )**0.5
# A user can find the distance of coordinates from origin
  def distance_from_origin(self):
    # return (self.x_cod**2 + self.y_cod**2)**0.5
    return self.euclidean_distance(point(0,0))
class Line:
  def  __init__(self,A,B,C):
    self.A = A
    self.B = B
    self.C = C
  def __str__(self):
    return '{}x + {}y + {} = 0'.format(self.A , self.B,self.C)
#A user can check if a point lies on given line
  def point_on_line(line,point):
    if line.A*point.x_cod + line.B*point.y_cod + line.C == 0:
      return 'lies on the line'
    else:
      return 'doesnot lies on the line'
# A user can find the shortest distance between a given 2D point and a given line
  def shortest_distance(line,point):
    return abs((line.A*point.x_cod + line.B*point.y_cod + line.C)/(line.A**2 + line.B**2)**0.5)

# %%
p1 = point(2,3)
p2 = point(1,1)
# <x,y>
p1.distance_from_origin()
# Out:
# 3.605551275463989

# %%
l1 = Line(3,4,5)
print(l1)
print(p1)
print(l1.point_on_line(p1))
print(p2)
print(l1.point_on_line(p2))
l1.shortest_distance(p1)
# Out:
# 3x + 4y + 5 = 0
# <2,3>
# doesnot lies on the line
# <1,1>
# doesnot lies on the line
# 4.6

# %% [markdown]
# # How object access attributes

# %%
class Person:

  def __init__ (self,name_input,country_input):
    self.name = name_input
    self.country = country_input

  def greet(self):
    if self.country == 'India':
      print("Namaste",self.name)
    else:
      print('Hello',self.name)

# %%
#how to access attributes
p = Person('Niharika','India')

# %%
p.name
# Out:
# 'Niharika'

# %%
#how to access methods
p.greet()
# Out:
# Namaste Niharika

# %% [markdown]
# # Attribute Creation from Outside of the class

# %%
p.gender = 'male'

# %%
p.gender
# Out:
# 'male'

# %% [markdown]
# # ReferenCE variable

# %%
# object without a reference
class Person:

  def __init__ (self):
    self.name = 'Niharika'
    self.country = 'india'

p = Person()
q = p

# %%
#multiple ref
print(id(p))
print(id(q))
# Out:
# 134058598116160
# 134058598116160

# %%
# change attribute value with the help of 2nd object

# %%
print(p.name)
print(q.name)
q.name = 'payal'
print(p.name)
print(q.name)
# Out:
# Niharika
# Niharika
# payal
# payal

# %% [markdown]
# #  Pass by reference

# %%
class Person:

  def __init__ (self,name , gender):
    self.name = name
    self.gender = gender
    # outside the class -> function
def greet(person):
  print('Hi my name is ',person.name , 'and i am a',person.gender)
  p1 = Person('nihu','female')
  return p1

p = Person('niharika','female')
x = greet(p)
print(x.name)
print(x.gender)
# Out:
# Hi my name is  niharika and i am a female
# nihu
# female

# %%
class Person:

  def __init__ (self,name , gender):
    self.name = name
    self.gender = gender
    # outside the class -> function
def greet(person):
  print(id(person))
  print('Hi my name is ',person.name , 'and i am a',person.gender)
  person.name = 'nihu'
  print(person.name)


p = Person('niharika','female')
print(id(p))
greet(p)
print(p.name)
# Out:
# 134058320489232
# 134058320489232
# Hi my name is  niharika and i am a female
# nihu
# nihu

# %% [markdown]
# #Object ki mutuality

# %%
class Person:

  def __init__ (self,name , gender):
    self.name = name
    self.gender = gender
    # outside the class -> function
def greet(person):
  person.name = 'nihu'
  return person

p = Person('niharika','female')
print(id(p))
p1 = greet(p)
print(id(p1))
# Out:
# 134058320477744
# 134058320477744

# %% [markdown]
# #Encapsulatin

# %%
class Atm:
  #constructor(special function)->superpower->
  def __init__(self):
    self.pin = ''
    self.__balance = 0
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if(type(new_value)) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')



  def __menu(self):
    user_input = input(
        """
        HI how can I help you
        1.press 1 to create pin
        2.press 2 to change pin
        3.press 3 to check balance
        4.press 4 to withdraw
        5.Anything else to exit
      """
    )

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
      pass
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance

    print('pin created successfully')


  def change_pin(self):
    old_pin = input("enter old pin")
    if old_pin == self.pin:
      #let this change the pin
      new_pin = input("enter new pin")
      self.pin = new_pin
      print('pin changed successfully')

    else:
      print('nai krne de skta h re baba')


  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is', self.__balance)
    else:
      print('chal nikal yhan se')



  def withdraw(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      #allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful balance is', self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
obj = Atm()

# %%
obj.get_balance()
# Out:
# 0

# %%
obj.set_balance(1000)

# %%
 obj.get_balance()
# Out:
# 1000

# %% [markdown]
# # Collections of object

# %%
#list of objects
class Person:

  def __init__(self,name,gender):
    self.name =  name
    self.gender = gender
p1 = Person('niharika','female')
p2 = Person('aditya','male')
p3 = Person('nihu','female')
p4 = Person('kunal','male')

L = [p1,p2,p3,p4]

for i in L:
  print(i.name,i.gender)
# Out:
# niharika female
# aditya male
# nihu female
# kunal male

# %%
#sets of objects
class Person:

  def __init__(self,name,gender):
    self.name =  name
    self.gender = gender
p1 = Person('niharika','female')
p2 = Person('aditya','male')
p3 = Person('nihu','female')
p4 = Person('kunal','male')

s = (p1,p2,p3,p4)

for i in s:
  print(i.name,i.gender)
# Out:
# niharika female
# aditya male
# nihu female
# kunal male

# %%
# can store in dictionary
class Person:

  def __init__(self,name,gender):
    self.name =  name
    self.gender = gender
p1 = Person('niharika','female')
p2 = Person('aditya','male')
p3 = Person('nihu','female')
p4 = Person('kunal','male')

d = {'p1':p1,'p2':p2,'p3':p3,'p4':p4}

for i in d:
  print(d[i].name)
  print(d[i].gender)
# Out:
# niharika
# female
# aditya
# male
# nihu
# female
# kunal
# male

# %% [markdown]
# #Static Variables(Vs Instance Variable)

# %%
class Atm:

  __counter = 1
  #constructor(special function)->superpower->
  def __init__(self):
    self.pin = ''
    self.__balance = 0
    self.cid = Atm.__counter
    Atm.__counter = Atm.__counter + 1

    #self.menu()
  def get_counter(self):
    return Atm.__counter

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if(type(new_value)) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')



  def __menu(self):
    user_input = input(
        """
        HI how can I help you
        1.press 1 to create pin
        2.press 2 to change pin
        3.press 3 to check balance
        4.press 4 to withdraw
        5.Anything else to exit
      """
    )

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
      pass
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance

    print('pin created successfully')


  def change_pin(self):
    old_pin = input("enter old pin")
    if old_pin == self.pin:
      #let this change the pin
      new_pin = input("enter new pin")
      self.pin = new_pin
      print('pin changed successfully')

    else:
      print('nai krne de skta h re baba')


  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is', self.__balance)
    else:
      print('chal nikal yhan se')



  def withdraw(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      #allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful balance is', self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
c1 = Atm()

# %%
c2 = Atm()

# %%
c3 = Atm()

# %%
c1.cid
# Out:
# 1

# %%
c2.cid
# Out:
# 2

# %%
c3.cid
# Out:
# 3

# %%
Atm.get_counter(self)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_34660/3921648507.py in <cell line: 0>()
# ----> 1 Atm.get_counter(self)
#
# NameError: name 'self' is not defined

# %% [markdown]
# # CLASS RELATIONSHIP
# * Aggregation
# * Inheritance

# %% [markdown]
# #Aggregation

# %%
#example
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.get_city(),self.address.pin,self.address.state)

  def edit_profile(self,new_name,new_city,new_pin,new_state):
    self.name = new_name
    self.address.edit_address(new_city,new_pin,new_state)




class Address:

  def __init__(self,city,pin,state):
    self.__city = city
    self.pin = pin
    self.state = state

  def get_city(self):
    return self.__city

  def edit_address(self,new_city,new_pin,new_state):
    self.__city = new_city
    self.pin = new_pin
    self.state = new_state



add1 = Address('gurgaon',122011,'haryana')
cust = Customer('niharika','female',add1)

cust.print_address()

cust.edit_profile('nihu','mumbai',11111,'maharastra')
cust.print_address()
#method example
#what about private attribute
# Out:
# gurgaon 122011 haryana
# mumbai 11111 maharastra

# %% [markdown]
# # Inheritance

# %%
#parent
class user:

  def __init__(self):
    self.name = 'nihu'
    self.gender = 'female'

  def login(self):
    print('login')

#child
class Student(user):

  def enroll(self):
    print('enroll into the course')

u = user()
s = Student()

print(s.name)
s.login()
s.enroll()
# Out:
# nihu
# login
# enroll into the course

# %%
#constructor example
class Phone:
  def __init__(self,price,brand ,camera):
    print('Inside phone constructor')
    self.price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print('Buying a phone')

class SmartPhone(Phone):
  pass


s = SmartPhone(20000,'Apple',13)
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
#constructor example
class Phone:
  def __init__(self,price,brand ,camera):
    print('Inside phone constructor')
    self.price = price
    self.brand = brand
    self.camera = camera

class SmartPhone(Phone):
  def __init__(self,os,ram):
    self.os = os
    self.ram = ram
    print('Inside SmartPhone Constructor')




s = SmartPhone('Android',2)
# Out:
# Inside SmartPhone Constructor

# %%
#child cant access private members of the class
class Phone:
  def __init__(self,price,brand ,camera):
    print('Inside phone constructor')
    self.__price = price
    self.brand = brand
    self.camera = camera

    #getter
  def show(self):
      print(self.__price)

class SmartPhone(Phone):
  def check(self):
    print(self.__price)




s = SmartPhone(20000,'Apple',13)
s.show()
# Out:
# Inside phone constructor
# 20000

# %%
class parent:

  def __init__(self,num):
    self.__num = num

  def get_num(self):
    return self.__num

class child(parent):

  def show(self):
    print('This is in child class')

son = child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
class A:
  def __init__(self):
    self.var1 = 100
  def display1(self,var1):
    print("class A:", self.var1)
class B(A):

  def display2(self,var1):
    print('class B: ',self.var1)

obj = B()
obj.display1(200)
# Out:
# class A: 100

# %%
#mathod overriding
class Phone:
  def __init__(self,price,brand ,camera):
    print('Inside phone constructor')
    self.price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print('Buying a phone')

class SmartPhone(Phone):
  def buy(self):
    print('buying a smartphone')




s = SmartPhone(20000,'Apple',13)
s.buy()
# Out:
# Inside phone constructor
# buying a smartphone

# %%
class Phone:
  def __init__(self,price,brand ,camera):
    print('Inside phone constructor')
    self.price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print('Buying a phone')

class SmartPhone(Phone):
  def buy(self):
    print('buying a smartphone')
    #syntax to call parent ka buy method
    super().buy()




s = SmartPhone(20000,'Apple',13)
s.buy()
# Out:
# Inside phone constructor
# buying a smartphone
# Buying a phone
