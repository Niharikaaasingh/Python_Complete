# %% [markdown]
# <a href="https://colab.research.google.com/github/Niharikaaasingh/Python_Complete/blob/main/1_PYTHON_FUNDAMENTALS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Salman khan")
# Out:
# Salman khan

# %%
print(7)
# Out:
# 7

# %%
print(True)
# Out:
# True

# %%
print("Hello" , 1 ,2 ,3 ,4 ,True)
# Out:
# Hello 1 2 3 4 True

# %%
print('Hello',1,4,5, sep ="/")
# Out:
# Hello/1/4/5

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print("hello", end="-")
print("world")
# Out:
# hello-world

# %% [markdown]
# # DATA TYPE

# %%
#int
print(8)
print(1e309)
# Out:
# 8
# inf

# %%
#Float /decimal
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#string
print("Hello world")
# Out:
# Hello world

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
#List->C->Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary
print({'name':'Nitin','gender':'Male'})
# Out:
# {'name': 'Nitin', 'gender': 'Male'}

# %%
#Type
type(3+5j)
# Out:
# complex

# %% [markdown]
# # VARIABLE

# %%
#static vs dyanmic typing
#static vs dynamic Binding
#stylish declaration Techniques

# %%
name = 'nitish'
print(name)
a = 5
b = 7
print(a + b)
# Out:
# nitish
# 12

# %%
#Dynamic Typing
a = 5
#static typing
#int a = 5
#python supports dynamic typing
#c/c++ java supports static typing

# %%
#dynamic binding-(kisi bhi type ka datatype handle kr skta h )
a = 5
print(a)
a = 'nitish'
print(a)

#static binding(ek baar jo initializa kr diya change nai kr skte not in python )
#int a = 5
# Out:
# 5
# nitish

# %%
a = 3
b = 4
c = 5
print(a,b,c)
# Out:
# 3 4 5

# %%
a,b,c=3,4,5
print(a,b,c)
# Out:
# 3 4 5

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %%
a=3
b =6
print(a+b)
# Out:
# 9

# %% [markdown]
# # KEYWORDS AND IDENTIFIERS

# %%
#keywords

# %%
#identifiers
# you cant start with a digit
name1 ='Nitish'
print(name1)
#you can use special chars underscore _
_ = "nitish"
print(_)
#identifiers camt be keywords
# Out:
# Nitish
# nitish

# %% [markdown]
# # User Input

# %%
#static vs Dynamic
input('Apna naam bta')
# Out:
# Apna naam btaNiharika Singh
# 'Niharika Singh'

# %%
#take input from user and store them in a variable
fnum =int( input('enter first number'))
Snum =int(input("enter second number"))
#add the 2 variable
result = fnum + Snum
# print the result
print(result)
print(type(fnum))
# Out:
# enter first number56
# enter second number67
# 123
# <class 'int'>

# %%
#take input from user and store them in a variable
fnum = input('enter first number')
Snum =input("enter second number")
#add the 2 variable
result = int(fnum )+ int(Snum)
# print the result
print(result)
print(type(fnum))
# Out:
# enter first number56
# enter second number67
# 123
# <class 'str'>

# %% [markdown]
# # TYPE CONVERSION

# %%
#implicit vs Explicit
print(5+5.6)
print(type(5),type(5.5))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
#explicit
#str-> int
int('4')
# Out:
# 4

# %% [markdown]
# # LITERALS

# %%
a = 0b1010 #binary literals
b =100 #Decimal Literals
c =0o310 #Octal literals
d = 0x12c #hexdacimal literals

 #float literal
float_1 = 10.5
float_2 = 1.5e2 #1.5 * 10^2
float_3 = 1.5e-3 #1.5 * 10^-3

#complex literal
x =3.14j
print(a, b, c , d)
print(float_1,float_2,float_3)
print(x)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j

# %%
#binary
x = 3.14j
print(x.real,x.imag)
# Out:
# 0.0 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:",a)
print("b:",b)
# Out:
# a: 5
# b: 10

# %%
a = None
print(a)
# Out:
# None
