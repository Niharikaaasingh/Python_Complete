# %% [markdown]
# <a href="https://colab.research.google.com/github/Niharikaaasingh/Python_Complete/blob/main/PYTHON_FUNCTIONS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # lets create function(with docstring)

# %%
def is_even(num):
  """
  This function returns if a given number is odd or even.
  input- any valid integer
  output- odd/even
  created on - 13th april 2026
  """
  if type(num) == int:
    if num % 2 == 0:
      return 'even'
    else:
      return 'odd'
  else:
    return 'pagal hai kyaa'

# %%
#function
#function name(input)
for i in range(1,11):
  x = is_even(i)
  print(x)
# Out:
# odd
# even
# odd
# even
# odd
# even
# odd
# even
# odd
# even

# %%
is_even('hello')
# Out:
# 'pagal hai kyaa'

# %% [markdown]
# # Types of Arguments
# * default argument
# * Positional Argument
# * Keyword Argument

# %%
#default argument
def power(a=1,b=1):
  return a**b

# %%
power(2)
# Out:
# 2

# %%
#positional argument
power(2,3)
# Out:
# 8

# %%
#keyword argument
power(b=3,a=2)
# Out:
# 8

# %% [markdown]
# # *args and **kwargs
# *args and *kwargs are special python keywords that are used to pass the variable length of arguments to a function

# %%
#  *args
# allows us to pass a variable number of non-keyword arguments to a function.
def multiply(*args):
  product = 1

  for i in args:
    product = product*i
  print(args)
  return product

# %%
multiply(2,3,4,5,6,7)
# Out:
# (2, 3, 4, 5, 6, 7)
# 5040

# %%
def sum(*nihu):
  add = 0

  for i in nihu:
    add = add + i
  print(nihu)
  return add

# %%
sum(1,4,8,9)
# Out:
# (1, 4, 8, 9)
# 22

# %%
# **kwargs
# allows us to pass  anu=y number of keyword arguments
# keyword arguments mean that they contain a key - value pair , like a python dictionary()

def display(**kwargs):

  for (key , value ) in kwargs.items():
    print(key,'->',value)

# %%
display(india='delhi',srilanka='colombo',nepal='katmandu')
# Out:
# india -> delhi
# srilanka -> colombo
# nepal -> katmandu

# %% [markdown]
# order matters in this
# order(normal-> *args->**kwargs)
# *args and **kwargs are conventional . you can changr it to your preference name

# %% [markdown]
# # Nested Functions

# %%
def f():
  def g():
    print('inside function g')
  g()
  print('inside function f')

# %% [markdown]
# #Functions are 1st Class citizens
#
# ----they act like datatype has datatypes rights

# %%
#type and id
def square(num):
  return num**2


type(square)

id(square)
# Out:
# 136896622458048

# %%
#reassign
x = square
id(x)
x(3)
# Out:
# 9

# %%
#deleting a function
del square
square(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17480/2386479958.py in <cell line: 0>()
#       1 #deleting a function
# ----> 2 del square
#       3 square(3)
#
# NameError: name 'square' is not defined

# %%
# storing
L = [1,2,3,4,square]
L[-1](3)
# Out:
# 9

# %%
# returning a function

# %%
def f():
  def x(a ,b):
    return a+b
  return x

val = f()(3,4)
print(val)
# Out:
# 7

# %%
# function as argument

# %%
def func_a():
  print('insider func_a')

def func_b(z):
  print('insider func_c')
  return z()

print(func_b(func_a))
# Out:
# insider func_c
# insider func_a
# None

# %% [markdown]
# # Lambda Function

# %%
#x -> x^2
a = lambda x:x**2
a(2)
# Out:
# 4

# %%
#x,y->x+y
a = lambda x,y:x+y
a(9,10)
# Out:
# 19

# %%
#check if a string has 'a'
a = lambda s:'a' in s
a('hello')
# Out:
# False

# %%
#odd or eve
a = lambda x:'even' if x%2 == 0 else 'odd'
a(11)
# Out:
# 'odd'

# %% [markdown]
# # Higher Order Function
# lambda is used with higher order function

# %%
#Example

def square(x):
  return x**2

def cube(x):
  return x**3

#HOF
def transform(f,L):  #ytransform is higher order function
  output = []
  for i in L:
    output.append(f(i))

  print(output)

L = [1,2,3,4,5]

transform(lambda x:x**3,L)
# Out:
# [1, 8, 27, 64, 125]

# %% [markdown]
# #Map

# %%
#square the items of a list
list(map(lambda x:x**2 , [1,2,3,4,5]))
# Out:
# [1, 4, 9, 16, 25]

# %%
#odd/even labelling of list items
L = [1,2,3,4,5]
list(map(lambda x:'even' if x%2 == 0 else 'odd',L))
# Out:
# ['odd', 'even', 'odd', 'even', 'odd']

# %% [markdown]
# # Filter

# %%
#numbers greater than 5
L = [3,4,5,6,7]

list(filter(lambda x:x>5,L))
# Out:
# [6, 7]

# %%
# fetch fruits starting with 'a'
fruits = ['apple','guava','banana']

list(filter(lambda x:x.startswith('a'),fruits))
# Out:
# ['apple']

# %% [markdown]
# #Reduce

# %%
#sum of all items
import functools
functools.reduce(lambda x,y:x+y,[1,2,3,4,5])
# Out:
# 15

# %%
#find min
functools.reduce(lambda x,y:x if x<y else y, [23,45,11,10,61,22,1])
# Out:
# 1
